# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Read the data
weather_df = pd.read_csv("../WeatherPy/weather.csv",index_col=0)

weather_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       ushuaia -54.8000  -68.3000     51.80        71          40
# 1     maltahohe -24.8333   16.9833     66.06        32           0
# 2      khorixas -20.3667   14.9667     72.32        33          17
# 3        hobart -42.8794  147.3294     73.40        49          75
# 4  punta arenas -53.1500  -70.9167     53.60        71          75
#
#    Wind Speed Country        Date
# 0       16.11      AR  1615592024
# 1        2.64     NaN  1615592172
# 2        1.21     NaN  1615592172
# 3       17.27      AU  1615592173
# 4       24.16      CL  1615592173

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#Google developer API key

print(g_key)
# Out:
# AIzaSyANyBcsF7imNAZRPogHNsRAPkoHmas3nFM

# %%
#geocordinates
target_cordinates = "-54.8000, -68.3000"
target_radius = 300
target_type = "lodging"

#set up a parameters dictionary

params = {
    "location": target_cordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
print(response.url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-54.8000%2C+-68.3000&radius=300&type=lodging&key=AIzaSyANyBcsF7imNAZRPogHNsRAPkoHmas3nFM

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -54.8025087,
#                     "lng": -68.3004296
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -54.80118891970849,
#                         "lng": -68.2990601197085
#                     },
#                     "southwest": {
#                         "lat": -54.80388688029149,
#                         "lng": -68.3017580802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "MS Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 600,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104905646853372602087\">MS Hotel</a>"
#                     ],
#                     "photo_reference": "ATtYBwK7M-olviqGLfH7d09mgHxyMXJusIAPpzu01hoHbWALK3iHjmag0bFaAWQmeE6WDwuZdBcH9E3ybysDhJpwqTtWp4PbyDcUefQc-heKP6ghOIglxWkABFppwbmw55d8ELq7gHuUTr_Qj1l_7hIy2BwWc-Wsoa_JxEku0LJjlCPDwxIV",
#                     "width": 800
#                 }
#             ],
#             "place_id": "ChIJ27W1eVAjTLwRkT2BKFa5BzU",
#             "plus_code": {
#                 "compound_code": "5MWX+XR Ushuaia, Tierra del Fuego Province, Argentina",
#                 "global_code": "37QH5MWX+XR"
#             },
#             "rating": 5,
#             "reference": "ChIJ27W1eVAjTLwRkT2BKFa5BzU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Gobernador Ernesto Manuel Campos 22, Ushuaia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -54.8025171,
#                     "lng": -68.30030339999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -54.8011648197085,
#                         "lng": -68.29895671970849
#                     },
#                     "southwest": {
#                         "lat": -54.8038627802915,
#                         "lng": -68.3016546802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Departamentos del mar",
#             "photos": [
#                 {
#                     "height": 316,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117298760866733699158\">Florencia Fossati</a>"
#                     ],
#                     "photo_reference": "ATtYBwKzaCvI9tON-e9hjirslFSfMYzfLyGZekhNozaQdV9HMwvf4PwsKTXECFoRRnjLY9PDGOdlkSd3EbXaIoOiwUnXr1nieD4ZjIaT59XrYIfNn-4dlV1HGzBxKLqO-mx13Z5ETX7M13snywRAPVFP8k9dyGNaKMpCZuvxwsDp1RkRJ48L",
#                     "width": 424
#                 }
#             ],
#             "place_id": "ChIJzfqk7Q0jTLwRIBf1l5T8PH4",
#             "plus_code": {
#                 "compound_code": "5MWX+XV Ushuaia, Tierra del Fuego Province, Argentina",
#                 "global_code": "37QH5MWX+XV"
#             },
#             "reference": "ChIJzfqk7Q0jTLwRIBf1l5T8PH4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Gdor. Ernesto Manuel Campos 88-1, V9410AVB, Ushuaia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -54.8019121,
#                     "lng": -68.3029511
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -54.8006915197085,
#                         "lng": -68.3015024697085
#                     },
#                     "southwest": {
#                         "lat": -54.80338948029149,
#                         "lng": -68.30420043029152
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Ushuaia",
#             "place_id": "ChIJce7UZ4EjTLwRFg8xHGaMlzk",
#             "plus_code": {
#                 "compound_code": "5MXW+6R Ushuaia, Tierra del Fuego Province, Argentina",
#                 "global_code": "37QH5MXW+6R"
#             },
#             "reference": "ChIJce7UZ4EjTLwRFg8xHGaMlzk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Ushuaia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -54.8019121,
#                     "lng": -68.3029511
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -54.8006915197085,
#                         "lng": -68.3015024697085
#                     },
#                     "southwest": {
#                         "lat": -54.80338948029149,
#                         "lng": -68.30420043029152
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel las lengas",
#             "photos": [
#                 {
#                     "height": 2967,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113861499634425843247\">Melina Fischer</a>"
#                     ],
#                     "photo_reference": "ATtYBwIX6d_XTJqkxkXnOjElvZX6D8EraM20uU1tJYbZ2ZlHhhyJ30-So4lgI1pm3lCqIA4HIqiHmtRxeKuWhSjavtdsffoSiDhNZuVusYBJ9jDkfJ1kto8SNm6AXO-60XCyyR1FjOf7jSUgn9B8bcGsB4Rg4A2sfDKbkPzRXiwgbi0Nuwtb",
#                     "width": 1668
#                 }
#             ],
#             "place_id": "ChIJa5xxKu8jTLwRoA4LuZkfK1c",
#             "plus_code": {
#                 "compound_code": "5MXW+6R Ushuaia, Tierra del Fuego Province, Argentina",
#                 "global_code": "37QH5MXW+6R"
#             },
#             "rating": 4.5,
#             "reference": "ChIJa5xxKu8jTLwRoA4LuZkfK1c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "Ushuaia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -54.8019121,
#                     "lng": -68.3029511
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -54.8006915197085,
#                         "lng": -68.3015024697085
#                     },
#                     "southwest": {
#                         "lat": -54.80338948029149,
#                         "lng": -68.30420043029152
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Ushuaia",
#             "place_id": "ChIJy_LlzXAjTLwRl4UCnJUT8ls",
#             "plus_code": {
#                 "compound_code": "5MXW+6R Ushuaia, Tierra del Fuego Province, Argentina",
#                 "global_code": "37QH5MXW+6R"
#             },
#             "reference": "ChIJy_LlzXAjTLwRl4UCnJUT8ls",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Yaganes 407-589, Ushuaia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -54.8019121,
#                     "lng": -68.3029511
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -54.8006915197085,
#                         "lng": -68.3015024697085
#                     },
#                     "southwest": {
#                         "lat": -54.80338948029149,
#                         "lng": -68.30420043029152
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "desdemona",
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115402177588726206598\">Nico Loiacono</a>"
#                     ],
#                     "photo_reference": "ATtYBwL8Nd1eg10zchJOjGPe8oYZX8Jk4TEAE2xtxVly9SWiRTWkA9qc-Y_9kM9oXpqhr8CFxLdoPPPjuIeLo0aa1ngMUDI0tO9_hWwuP_OoOrCpQChPBw1Du2QN5c3rJoq87ydZdzzsH3hKs-5sZvA3cuc3Q90eBbgSxLsuK2zpnmNaIVVg",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJdQWY_hojTLwR-41_LV__Xfw",
#             "plus_code": {
#                 "compound_code": "5MXW+6R Ushuaia, Tierra del Fuego Province, Argentina",
#                 "global_code": "37QH5MXW+6R"
#             },
#             "rating": 3,
#             "reference": "ChIJdQWY_hojTLwR-41_LV__Xfw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Ushuaia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -54.8019121,
#                     "lng": -68.3029511
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -54.8006915197085,
#                         "lng": -68.3015024697085
#                     },
#                     "southwest": {
#                         "lat": -54.80338948029149,
#                         "lng": -68.30420043029152
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Buenos aires",
#             "place_id": "ChIJXSG9bVsjTLwR6RkDz5l7xf0",
#             "plus_code": {
#                 "compound_code": "5MXW+6R Ushuaia, Tierra del Fuego Province, Argentina",
#                 "global_code": "37QH5MXW+6R"
#             },
#             "reference": "ChIJXSG9bVsjTLwR6RkDz5l7xf0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Ushuaia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -54.8019121,
#                     "lng": -68.3029511
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -54.8006915197085,
#                         "lng": -68.3015024697085
#                     },
#                     "southwest": {
#                         "lat": -54.80338948029149,
#                         "lng": -68.30420043029152
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Ushuaia Flat III",
#             "place_id": "ChIJfSd4OJ8jTLwRZ0TcHQMxrJ8",
#             "plus_code": {
#                 "compound_code": "5MXW+6R Ushuaia, Tierra del Fuego Province, Argentina",
#                 "global_code": "37QH5MXW+6R"
#             },
#             "rating": 5,
#             "reference": "ChIJfSd4OJ8jTLwRZ0TcHQMxrJ8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Altos de, Fortunato Beban n 1188, Ushuaia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -54.8019121,
#                     "lng": -68.3029511
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -54.8006915197085,
#                         "lng": -68.3015024697085
#                     },
#                     "southwest": {
#                         "lat": -54.80338948029149,
#                         "lng": -68.30420043029152
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "990 Km De La ANT\u00c1RTIDA",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107454678077344476765\">Maria Victoria Arosemena Villacres</a>"
#                     ],
#                     "photo_reference": "ATtYBwL1fNyE4DWcMezdYmlwm7mMVDDtpLr7l24ScZS6pR3Bsyqvx3CS2j7Tue8KdBbTTtVrzCTRghTwNd-sViwk8m559xzWK17ljTFGLatqzkBlhUvj6W261Qa8BMoWNafMr3aJs7qa2nIKJV8fE8DuCaELfvxCVIqbxkfEYoi1bRpFeOGp",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJSe3PDy8jTLwRSKC-CmJBq2Q",
#             "plus_code": {
#                 "compound_code": "5MXW+6R Ushuaia, Tierra del Fuego Province, Argentina",
#                 "global_code": "37QH5MXW+6R"
#             },
#             "reference": "ChIJSe3PDy8jTLwRSKC-CmJBq2Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Isla Grande de Tierra del Fuego. De la Ermita 3462, 9410"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -54.8019121,
#                     "lng": -68.3029511
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -54.8006915197085,
#                         "lng": -68.3015024697085
#                     },
#                     "southwest": {
#                         "lat": -54.80338948029149,
#                         "lng": -68.30420043029152
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Apart Hotel Alem",
#             "place_id": "ChIJTUkuw94iTLwRRWMwdSWpuGw",
#             "plus_code": {
#                 "compound_code": "5MXW+6R Ushuaia, Tierra del Fuego Province, Argentina",
#                 "global_code": "37QH5MXW+6R"
#             },
#             "rating": 5,
#             "reference": "ChIJTUkuw94iTLwRRWMwdSWpuGw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Ushuaia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -54.8019121,
#                     "lng": -68.3029511
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -54.8006915197085,
#                         "lng": -68.3015024697085
#                     },
#                     "southwest": {
#                         "lat": -54.80338948029149,
#                         "lng": -68.30420043029152
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Caba\ufffdas Rio Olivia",
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108857290718281001528\">Agustin Chiberry</a>"
#                     ],
#                     "photo_reference": "ATtYBwKIKWnZl8YmfMkxitd8GPMx-iWdBs2ODhViN5HrAVVc0HRS7suS4HBzzY1QAcUro9VYlo7ykxvqNFj6sXjF9UtU-pUie-3Fwk9nNX_3CLAxcxFNWkxL0ozF0Q1Dbyyx8xz7CBRIoodeEKVHghXcoyL8xWyvxyOAaL3ljesR5ojIHqke",
#                     "width": 2560
#                 }
#             ],
#             "place_id": "ChIJTUkuw94iTLwRiggRP45UNKg",
#             "rating": 5,
#             "reference": "ChIJTUkuw94iTLwRiggRP45UNKg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Sin Nombre 4700, Ushuaia, Tierra del Fuego"
#         }
#     ],
#     "status": "OK"
# }

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# * Narrow down the DataFrame to find ideal weather condition for my vacation.
#   * A max temperature lower than 100 degrees but higher than 80.
#   * Wind speed up to 15 mph.
#   * Humidity from 40% to 65%
weather_df.loc[weather_df["Max Temp"]>80]
weather_df["my_temp"] = weather_df["Max Temp"].between(80, 100, inclusive = False)
weather_df["my_wind"] = weather_df["Wind Speed"].between(0, 15, inclusive = True)
weather_df["my_humidity"] = weather_df["Humidity"].between(40, 65, inclusive = True)

weather_df
my_places =[]
for row in range(len(weather_df)):
    if weather_df.iloc[row,9] == True:
        if weather_df.iloc[row,10] == True:
            if weather_df.iloc[row,11] == True:
                my_places.append(weather_df.iloc[row,:])
                
my_place_df = pd.DataFrame(my_places)

#Drop any rows will null values.
my_place_df.dropna()    
my_place_df
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 14                kaduna  10.5222    7.4383     80.42        43          60
# 47   santiago del estero -27.7951  -64.2615     80.51        42          22
# 82             kavaratti  10.5669   72.6420     82.96        63           0
# 84             guadalupe  25.6833 -100.2500     87.80        40          20
# 105            hithadhoo  -0.6000   73.0833     83.32        62          54
# 157                kieta  -6.2167  155.6333     84.78        63          59
# 197                  voh -20.9667  164.7000     84.07        61          55
# 203                paita  -5.0892  -81.1144     82.40        57           0
# 245                 poya -21.3500  165.1500     83.01        60          41
# 305               faanui -16.4833 -151.7500     83.08        65          49
# 312                 yaan   7.3833    8.5667     83.19        62          97
# 322               jardim -21.4803  -56.1381     81.32        60          48
# 339               noumea -22.2763  166.4572     84.99        54          75
# 402        san cristobal   7.7669  -72.2250     80.60        61          40
# 404     puerto armuelles   8.2833  -82.8667     87.80        55          20
# 407             lorengau  -2.0226  147.2712     85.06        62          94
# 413       puerto carreno   6.1890  -67.4859     88.30        45          89
# 431              vaitape -16.5167 -151.7500     83.08        65          51
# 481              jalingo   8.8833   11.3667     83.30        52          84
# 483               olinda  -8.0089  -34.8553     80.60        65          40
# 496             santa fe -31.6333  -60.7000     81.00        61          92
# 568             karratha -20.7377  116.8463     86.83        57           1
#
#      Wind Speed Country        Date  my_temp  my_wind  my_humidity
# 14         3.49      NG  1615592179     True     True         True
# 47         7.63      AR  1615592203     True     True         True
# 82         1.59      IN  1615592223     True     True         True
# 84        10.36      MX  1615592224     True     True         True
# 105        5.84      MV  1615592043     True     True         True
# 157        5.50      PG  1615592264     True     True         True
# 197        6.11      NC  1615592287     True     True         True
# 203        9.22      PE  1615592290     True     True         True
# 245        5.32      NC  1615592317     True     True         True
# 305        2.46      PF  1615592351     True     True         True
# 312        9.93      NG  1615592355     True     True         True
# 322        3.53      BR  1615592360     True     True         True
# 339        3.44      NC  1615592268     True     True         True
# 402        4.61      VE  1615592409     True     True         True
# 404        5.75      PA  1615592410     True     True         True
# 407        4.23      PG  1615592412     True     True         True
# 413        8.08      CO  1615592415     True     True         True
# 431        2.48      PF  1615592425     True     True         True
# 481        5.61      NG  1615592455     True     True         True
# 483        9.22      BR  1615592456     True     True         True
# 496        4.00      AR  1615592225     True     True         True
# 568        3.18      AU  1615592503     True     True         True

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
hotel_layer = gmaps.marker_layer(locations, \ 
                                info_box_contents = [f"{info}" for info in hotel_info])

# Display figure
fig.add_layer(heat_layer)
fig.add_layer(hotel_layer)
fig
